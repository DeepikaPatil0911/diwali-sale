# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("Diwali Sales Data.csv",encoding='unicode_escape')

# %%
df.shape
# Out:
# (11250, 15)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11250 entries, 0 to 11249
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11250 non-null  int64
#  1   Cust_name         11250 non-null  object
#  2   Product_ID        11250 non-null  object
#  3   Gender            11250 non-null  object
#  4   Age Group         11250 non-null  object
#  5   Age               11250 non-null  int64
#  6   Marital_Status    11250 non-null  int64
#  7   State             11250 non-null  object
#  8   Zone              11250 non-null  object
#  9   Occupation        11250 non-null  object
#  10  Product_Category  11250 non-null  object
#  11  Orders            11250 non-null  int64
#  12  Amount            11238 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.drop(['Status','unnamed1'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11250 entries, 0 to 11249
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11250 non-null  int64
#  1   Cust_name         11250 non-null  object
#  2   Product_ID        11250 non-null  object
#  3   Gender            11250 non-null  object
#  4   Age Group         11250 non-null  object
#  5   Age               11250 non-null  int64
#  6   Marital_Status    11250 non-null  int64
#  7   State             11250 non-null  object
#  8   Zone              11250 non-null  object
#  9   Occupation        11250 non-null  object
#  10  Product_Category  11250 non-null  object
#  11  Orders            11250 non-null  int64
#  12  Amount            11238 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
pd.isnull(df)
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11245    False      False       False   False      False  False
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.shape
# Out:
# (11250, 13)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (11238, 13)

# %%
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df["Amount"] = df["Amount"].astype('int')

# %%
df["Amount"].dtypes
# Out:
# dtype('int32')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#rename column
df.rename(columns = {'Marital_Status':'Shadi'})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Shadi  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28      0
# 1      1000732       Kartik  P00110942      F     26-35   35      1
# 2      1001990        Bindu  P00118542      F     26-35   35      1
# 3      1001425       Sudevi  P00237842      M      0-17   16      0
# 4      1000588         Joni  P00057942      M     26-35   28      1
# ...        ...          ...        ...    ...       ...  ...    ...
# 11245  1000695      Manning  P00296942      M     18-25   19      1
# 11246  1004089  Reichenbach  P00171342      M     26-35   33      0
# 11247  1001209        Oshin  P00201342      F     36-45   40      0
# 11248  1004023       Noonan  P00059442      M     36-45   37      0
# 11249  1002744      Brumley  P00281742      F     18-25   19      0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123800e+04  11238.000000    11238.000000  11238.000000  11238.000000
# mean   1.003004e+06     35.411639        0.420093      2.489767   9452.630450
# std    1.716114e+03     12.753709        0.493595      1.114928   5221.553736
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001491e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004427e+06     43.000000        1.000000      3.000000  12673.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
# use describe() for specific columns
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11238.000000  11238.000000  11238.000000
# mean      35.411639      2.489767   9452.630450
# std       12.753709      1.114928   5221.553736
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12673.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# **Gender**

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ax = sns.countplot(x = "Gender", data = df,hue="Gender")

# %%
ax = sns.countplot(x = "Gender", data = df) 

for bar in ax.containers:
    ax.bar_label(bar)

# %% [markdown]
# **From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men**

# %%
df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
# Out:
#   Gender    Amount
# 0      F  74315385
# 1      M  31913276

# %%
sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
bl = sns.barplot(x="Gender",y="Amount",data = sales_gen)

for bars in bl.containers:
    bl.bar_label(bars)

# %% [markdown]
# **From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men**

# %% [markdown]
# # Age

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sns.countplot(data=df, x="Age Group", hue="Gender")
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %%
ax = sns.countplot(data=df,x="Age Group",hue="Gender")

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_age = df.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

colors = ['blue','green','pink','black','yellow','orange','purple']
# sns.barplot(data=sales_age, x='Age Group',y="Amount")

bl=sns.barplot(data=sales_age,x='Age Group',y='Amount',palette = colors)

for bars in bl.containers:
    bl.bar_label(bars)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_30072\3289046196.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bl=sns.barplot(data=sales_age,x='Age Group',y='Amount',palette = colors)

# %% [markdown]
# **From above graphs we can see that most of the buyers are of age group between 26-35 yrs female**

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %% [markdown]
# # State

# %%
df.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=True)
# Out:
#                State  Orders
# 13         Telangana     312
# 11            Punjab     495
# 12         Rajasthan     555
# 15       Uttarakhand     823
# 6          Jharkhand     953
# 1              Bihar    1062
# 3            Gujarat    1066
# 4            Haryana    1109
# 8             Kerala    1137
# 5   Himachal Pradesh    1568
# 0     Andhra Pradesh    2051
# 9     Madhya Pradesh    2252
# 2              Delhi    2740
# 7          Karnataka    3240
# 10       Maharashtra    3810
# 14     Uttar Pradesh    4807

# %%
# plt.figure(figsize=(16,9))
# sales_state = df.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False)
sales_state = df.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=sales_state,x="State",y="Orders",)
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
# plt.figure(figsize=(16,9))
sales_state = df.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False)

sns.barplot(data=sales_state,x="Orders",y="State")
# Out:
# <Axes: xlabel='Orders', ylabel='State'>

# %% [markdown]
# **From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively**

# %% [markdown]
# # Marital Status

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ax = sns.countplot(data=df, x="Marital_Status")
sns.set(rc={'figure.figsize':(6,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Marital_Status'], as_index = False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(data=sales_state,x="Marital_Status",y="Amount")
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %%
sales_state = df.groupby(['Marital_Status','Gender'], as_index = False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(data=sales_state,x="Marital_Status",y="Amount",hue="Gender")
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# **From above graphs we can see that most of the buyers are married (women) and they have high purchasing power**

# %% [markdown]
# # Occupation

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ax = sns.countplot(data=df,x="Occupation")

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['Occupation'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=sales_state,x="Occupation", y="Amount")
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# **From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector**

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %% [markdown]
# # Zone

# %%
ax = sns.countplot(data=df,x='Zone')

sns.set(rc={'figure.figsize':(10,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_zone = df.groupby(["Zone"],as_index=False)['Amount'].sum().sort_values(by='Amount')
color = ['green','blue','pink','black','grey']
sns.barplot(data=sales_zone,x="Zone",y="Amount")
# Out:
# <Axes: xlabel='Zone', ylabel='Amount'>

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %% [markdown]
# # Product Category

# %%
ax = sns.countplot(data = df, x="Product_Category")
sns.set(rc={"figure.figsize":(25,9)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_product = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(8)

sns.barplot(data=sales_product,x='Product_Category',y='Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %%
fig1,ax1 = plt.subplots(figsize=(12,7))
df.groupby('Product_Category')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category'>

# %% [markdown]
# # Conclusion

# %% [markdown]
# **Married women age group 26-35 yrs from UP, Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category**
